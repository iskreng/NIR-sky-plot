# %%
# %matplotlib inline

# %%
run NIR_ohlines.py
# Out:
# Enter telluric line file [default: atran0.85-2.4.dat] :
# Enter sky emission lines file [default: rousselot2000.txt] :
# Ha = 2.10048 um
# Target at z= 2.2 has Halpa line at 2.10048 um
