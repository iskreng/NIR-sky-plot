# %%
# %matplotlib inline

# %%
run NIR_ohlines.py
# Out:
# Enter central wavelength in um [default: 2.1]:
# Enter target redshift [default: 2.2]:
# Enter choice a (A3, F3, G2, K3, QSO) of reference template (lgg=3.4, Fe/H=0.0) spectrum [default: G2]:
#
# Few emission lines for z= 2.2 :
#              line  wavelength  z-shifted
# 0    $H_{\alpha}$   6562.8433   2.100110
# 1     $H_{\beta}$   4861.2786   1.555609
# 2    $H_{\gamma}$   4340.4620   1.388948
# 3    $H_{\delta}$   4101.7400   1.312557
# 4             OII   3727.0000   1.192640
# 5            OIII   5007.0000   1.602240
# 6             NII   6549.8000   2.095936
# 7             NII   6585.3000   2.107296
# 8   $Ly_{\alpha}$   1215.6700   0.389014
# 9    $Ly_{\beta}$   1025.7200   0.328230
# 10      C${\ IV}$   1549.0600   0.495699
# 11     $Mg{\ II}$   2798.7500   0.895600
