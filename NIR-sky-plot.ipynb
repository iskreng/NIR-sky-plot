# %%
# %matplotlib inline

# %%
run NIR_ohlines.py
# Out:
# Enter central wavelength in um [default: 2.1]: 2.29
# Enter target redshift [default: 2.2]: 0
# Enter choice a (A3, F3, G2, K3) of reference template (lgg=3.4, Fe/H=0.0) spectrum [default: G2]: K3
#
# For a target at z= 0.0 :
#            line  wavelength  z-shifted
# 0  $H_{\alpha}$      6564.0     0.6564
# 1   $H_{\beta}$      4862.0     0.4862
# 2          OIII      5007.0     0.5007
